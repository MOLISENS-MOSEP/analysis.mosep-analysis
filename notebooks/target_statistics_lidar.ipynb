# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from src.data import config
from src.data import get_timeseries_data, get_pointcloud_data

import numpy as np
import pandas as pd
from pointcloudset import PointCloud, Dataset
from rich import print as rprint

import plotly.graph_objects as go

# %% [markdown]
# #### Load Metadata from Bagfile

# %%
bag_file = "/workspaces/MOLISENSext_analysis/data/1raw/bad_aussee/data/molisens_met_2023_04_14-09_23_34"

# %%
TOPICS = ["/sensing/lidar/points", "/sensing/lidar/points2"]

# %%
dataset = get_pointcloud_data.load_pointcloudset(
    "/workspaces/MOLISENSext_analysis/data/2interim/bad_aussee/data",
    "molisens_met_2023_04_14-09_23_34_converted",
    topic="/sensing/lidar/points",
    verbose=True,
)
# Out:
# Searching for pointcloudset files in
# /workspaces/MOLISENSext_analysis/data/2interim/bad_aussee/data/pointcloudset/sensing_lidar_points/molisens_met_2023
# _04_14-09_23_34_converted
# Dataset loaded from
# /workspaces/MOLISENSext_analysis/data/2interim/bad_aussee/data/molisens_met_2023_04_14-09_23_34_converted
# start = 2023-04-14 07:23:41.000433
# end =   2023-04-14 08:28:24.306026
# end =   1:04:43.305593
# length =  16765
# avg frequency =  4.32 Hz
